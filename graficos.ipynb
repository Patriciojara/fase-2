# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Datos originales
residual = [
    732, 732, 732, 732, 732, 732, 732, 732, 732, 732,
    774, 1100, 1254, 1024, 732, 732, 732, 732, 732, 521,
    521, 521, 521, 521
]

total = [
    1351.93, 1353.24, 1350.98, 1347.02, 1345.44, 1343.51,
    1370.46, 1582.42, 1851.48, 2062.35, 2222.72, 2311.21,
    2343.34, 2300.22, 2191.04, 2005.19, 1772.91, 1494.52,
    1396.09, 1375.75, 1363.59, 1357.92, 1353.34, 1352.88
]

bi = [
    620, 621, 619, 615, 613, 612, 639, 850, 1119, 1330,
    1470, 1395, 1350, 1422, 1459, 1273, 1041, 763, 664,
    855, 843, 837, 833, 832
]

# Nuevo vector demanda
demanda = [
    7386, 7043, 6798, 6633, 6598, 6600, 6740, 6928, 7270,
    7665, 7955, 8115, 8193, 8250, 8282, 8237, 8169, 8063,
    8123, 8247, 8325, 8395, 8103, 7770
]

# Convertir listas a arrays de NumPy
bi_array = np.array(bi)
residual_array = np.array(residual)
total_array = np.array(total)
demanda_array = np.array(demanda)

# Restar los vectores
resultado = demanda_array - total_array
resultado_re = resultado + residual_array


# Crear el gráfico
#plt.plot(residual, label='Residual')
#plt.plot(total, label='Total')
#plt.plot(bi, label='Contratos')
plt.plot(demanda, label='Demanda Original', color='orange')  # Agregar la demanda con un estilo de línea discontinua
plt.plot(resultado_re, label='Demanda Residual', color='red')
plt.plot(resultado, label='Demanda Residual Esperada', linestyle='dashed')

plt.axis([-1, 24, 4000, 10000])
plt.xticks(np.arange(0, 24, 1))# Personalizar el gráfico
plt.title('Demanda diaria')
plt.xlabel('Horas')
plt.ylabel('Demanda [MW]')
plt.legend()

plt.savefig('grafico_demanda_residual.png')

# Mostrar el gráfico
plt.show()

# %%
print("hola mundo")
# Out:
# hola mundo

# %% [markdown]
# # Hola
